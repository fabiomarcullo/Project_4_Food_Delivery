# %%
import numpy as np
import pandas as pd
# import hvplot.pandas
from pathlib import Path
from sklearn.linear_model import LinearRegression

# %%
file_path = Path("Restaurant_DB_File.csv")
df_resturant = pd.read_csv(file_path)

# Display sample data
df_resturant.head()
# Out:
#      id                                 restaurant_name rating  \
# 0  2131  FINE FOOD MARKET (Convenience @ Bay & Gerrard)    4.8
# 1  2132                     McDonald's (Front & George)    4.8
# 2  2133            7-Eleven (372 Bay Street @ Richmond)    4.5
# 3  2134              Sunset Grill (1 Richmond St. West)    4.6
# 4  2135             Starbucks (485 Church at Wellesley)    4.9
#
#                category                                          address  \
# 0              American                      711 Bay St, Toronto, ON M5G
# 1               Burgers                  121 Front St E, Toronto, ON M5A
# 2                 Wings   372 Bay Street @ Richmond, Toronto, ON M5H 2W9
# 3  Breakfast and brunch  1 Richmond St. West (#130), Toronto, ON M5H 3W4
# 4                Bakery           485 Church Street, Toronto, ON M4Y 2C6
#
#     latitude  longitude province
# 0  43.658823 -79.384652       ON
# 1  43.649492 -79.370456       ON
# 2  43.651016 -79.381518       ON
# ...
