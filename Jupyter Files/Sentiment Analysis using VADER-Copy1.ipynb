# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Download VADER lexicon (only required once)
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Fabio_UofT
# [nltk_data]     SCS\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Read the dataset
restaurants_df = pd.read_csv("Restaurants_Yelp_Reviews.csv")

# %%
# Print DF
restaurants_df.head()
# Out:
#   Restaurant_name        Category  \
# 0  The Flying Pig  Canadian (New)
# 1  The Flying Pig  Canadian (New)
# 2  The Flying Pig  Canadian (New)
# 3  The Flying Pig  Canadian (New)
# 4  The Flying Pig  Canadian (New)
#
#                                              Address Province   Latitude  \
# 0  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 1  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 2  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 3  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 4  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
#
#     Longitude  Rating                                             Review
# 0 -123.122038       4  Busy place - strongly suggest a reservation. G...
# 1 -123.122038       4  I recommend Squid is the best part. I ordered ...
# 2 -123.122038       5  I really enjoyed my lunch at this cozy little ...
# 3 -123.122038       5  Ambiance is great with a great mixture of wood...
# 4 -123.122038       5  We went to the Flying Pig for dinner last nigh...

# %%
# Text Preprocessing
restaurants_df['Review'] = restaurants_df['Review'].astype(str)
restaurants_df['Review'] = restaurants_df['Review'].apply(lambda review: review.lower())
restaurants_df['Review'] = restaurants_df['Review'].str.replace('[^\w\s]', '')
# Out:
# C:\Users\Fabio_UofT SCS\AppData\Local\Temp\ipykernel_7380\3173914631.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   restaurants_df['Review'] = restaurants_df['Review'].str.replace('[^\w\s]', '')

# %%
# Perform Sentiment Analysis using VADER
analyzer = SentimentIntensityAnalyzer()

def get_sentiment_polarity(review):
    return analyzer.polarity_scores(review)['compound']

restaurants_df['Sentiment_score'] = restaurants_df['Review'].apply(get_sentiment_polarity)

# %%
# Categorize reviews as positive or negative based on sentiment score
threshold = 0.5  # You can adjust this threshold based on your preference
restaurants_df['Sentiment'] = restaurants_df['Sentiment_score'].apply(lambda score: 'Good' if score >= threshold else 'Bad')

# %%
# Print DF
restaurants_df.head()
# Out:
#   Restaurant_name        Category  \
# 0  The Flying Pig  Canadian (New)
# 1  The Flying Pig  Canadian (New)
# 2  The Flying Pig  Canadian (New)
# 3  The Flying Pig  Canadian (New)
# 4  The Flying Pig  Canadian (New)
#
#                                              Address Province   Latitude  \
# 0  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 1  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 2  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 3  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 4  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
#
#     Longitude  Rating                                             Review  \
# 0 -123.122038       4  busy place  strongly suggest a reservation gre...
# 1 -123.122038       4  i recommend squid is the best part i ordered g...
# 2 -123.122038       5  i really enjoyed my lunch at this cozy little ...
# 3 -123.122038       5  ambiance is great with a great mixture of wood...
# 4 -123.122038       5  we went to the flying pig for dinner last nigh...
#
#    Sentiment_score Sentiment
# 0           0.9485      Good
# 1           0.8979      Good
# 2           0.9966      Good
# 3           0.9892      Good
# 4           0.9845      Good

# %%
# Download the necessary resources for NLTK (run this once)
nltk.download('vader_lexicon')

# Initialize the SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Custom sentiment lexicon with positive and negative words and their scores
custom_lexicon = {
    'good': 0.5, 'great': 0.6, 'excellent': 0.7, 'awesome': 0.8, 'fantastic': 0.9,
    'bad': -0.5, 'poor': -0.6, 'terrible': -0.7, 'awful': -0.8, 'horrible': -0.9,
    'busy': 0.1,  # Custom sentiment score for 'busy'
    'delicious': 0.8,
    'yummy': 0.7,
    'tasty': 0.6,
    'delectable': 0.7,
    'flavorful': 0.6,
    'mouthwatering': 0.8,
    'savory': 0.6,
    'scrumptious': 0.7,
    'heavenly': 0.8,
    'exquisite': 0.7,
    'disappointing': -0.6,
    'tasteless': -0.5,
    'bland': -0.4,
    'overcooked': -0.6,
    'undercooked': -0.6,
    'greasy': -0.5,
    'salty': -0.4,
    'soggy': -0.5,
    'stale': -0.4,
    'unappetizing': -0.6,
    'joyful': 0.7,
    'happy': 0.6,
    'delighted': 0.7,
    'pleased': 0.6,
    'content': 0.5,
    'sad': -0.6,
    'unhappy': -0.5,
    'miserable': -0.7,
    'disheartened': -0.6,
    'gloomy': -0.5,
    'angry': -0.6,
    'frustrated': -0.5,
    'irritated': -0.5,
    'enraged': -0.7,
    'excited': 0.7,
    'thrilled': 0.8,
    'ecstatic': 0.9,
    'nervous': -0.5,
    'anxious': -0.6,
    'afraid': -0.6,
    'terrified': -0.8,
    'calm': 0.5,
    'relaxed': 0.6,
    'peaceful': 0.7
}

def extract_positive_negative_words(review):
    review = str(review)  # Ensure review is in string format
    words = review.split()
    positive_words = [word for word in words if custom_lexicon.get(word.lower(), 0) > 0]
    negative_words = [word for word in words if custom_lexicon.get(word.lower(), 0) < 0]
    return positive_words, negative_words, len(positive_words), len(negative_words)

# Assuming you have your DataFrame loaded and named 'restaurants_df'
restaurants_df['Positive Words'], restaurants_df['Negative Words'], restaurants_df['Positive Count'], restaurants_df['Negative Count'] = zip(*restaurants_df['Review'].apply(extract_positive_negative_words))

# Display the new DataFrame
print(restaurants_df)
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Fabio_UofT
# [nltk_data]     SCS\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#      Restaurant_name        Category  \
# 0     The Flying Pig  Canadian (New)
# 1     The Flying Pig  Canadian (New)
# 2     The Flying Pig  Canadian (New)
# 3     The Flying Pig  Canadian (New)
# 4     The Flying Pig  Canadian (New)
# ...              ...             ...
# 5503          Subway      Sandwiches
# 5504          Subway      Sandwiches
# 5505          Subway      Sandwiches
# 5506          Subway      Sandwiches
# 5507          Subway      Sandwiches
#
#                                                 Address Province   Latitude  \
# 0     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 1     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 2     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 3     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 4     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# ...                                                 ...      ...        ...
# 5503  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5504  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5505  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5506  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5507  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
#
#        Longitude  Rating                                             Review  \
# 0    -123.122038       4  busy place  strongly suggest a reservation gre...
# 1    -123.122038       4  i recommend squid is the best part i ordered g...
# 2    -123.122038       5  i really enjoyed my lunch at this cozy little ...
# 3    -123.122038       5  ambiance is great with a great mixture of wood...
# 4    -123.122038       5  we went to the flying pig for dinner last nigh...
# ...          ...     ...                                                ...
# 5503 -114.406515       1  worst sandwich ever given a 6 veggie with fing...
# 5504 -114.406515       4  subway is another must stop for my family when...
# 5505 -114.406515       1  the service here has been on the decline for s...
# 5506 -114.406515       1  this place has gone downhill and staff dont ca...
# 5507 -114.406515       4  ive only been here twice both times ordered th...
#
#       Sentiment_score Sentiment              Positive Words Negative Words  \
# 0              0.9485      Good  [busy, great, happy, good]             []
# 1              0.8979      Good                     [great]             []
# 2              0.9966      Good        [great, good, great]             []
# 3              0.9892      Good              [great, great]             []
# 4              0.9845      Good                 [excellent]             []
# ...               ...       ...                         ...            ...
# 5503           0.2960       Bad                          []             []
# 5504           0.9337      Good        [great, good, great]             []
# 5505           0.0478       Bad                          []             []
# 5506          -0.6860       Bad                          []             []
# 5507           0.4902       Bad                      [good]             []
#
#       Positive Count  Negative Count
# 0                  4               0
# 1                  1               0
# 2                  3               0
# 3                  2               0
# 4                  1               0
# ...              ...             ...
# 5503               0               0
# 5504               3               0
# 5505               0               0
# 5506               0               0
# 5507               1               0
#
# [5508 rows x 14 columns]

# %%
restaurants_df.sample(10)
# Out:
#                       Restaurant_name        Category  \
# 482                     Cafe FortyOne   Mediterranean
# 121           So Hyang Korean Cuisine          Korean
# 3161            Fourchette Antillaise    Cajun/Creole
# 3941             Saltwater Restaurant         Seafood
# 2563  The Old Triangle Irish Alehouse            Pubs
# 3310                         MR PATTY       Caribbean
# 5234                           Kazoku      Sushi Bars
# 3707      Browns Socialhouse Eastgate  Canadian (New)
# 1465        Silver Streams Restaurant         Chinese
# 568          Sawasdee Thai Restaurant            Thai
#
#                                                 Address Province   Latitude  \
# 482        5750 Oak Street Vancouver, BC V6M 2V9 Canada       BC  49.233718
# 121     6345 Fraser Street Vancouver, BC V5W 3A3 Canada       BC  49.227000
# 3161  5968 Rue de Salaberry Montreal, QC H4J 1J8 Canada       QC  45.526716
# 3941     320 Water Street St. John's, NL A1C 1C1 Canada       NL  47.561479
# 2563      5136 Prince Street Halifax, NS B3J 1L4 Canada       NS  44.647489
# 3310   5312 Patricia Avenue Montreal, QC H4V 1Z2 Canada       QC  45.460210
# 5234        30-2583 Pembina hwy Winnipeg, MB R3T Canada       MB  49.798829
# 3707      3610 Eastgate Drive Regina, SK S4Z 1A5 Canada       SK  50.451668
# 1465  7 St. Peters Road Charlottetown, PE C1A 5N3 Ca...      PEI  46.246684
# 568       4250 Main Street Vancouver, BC V5V 3P9 Canada       BC  49.247056
#
#        Longitude  Rating                                             Review  \
# 482  -123.127746       5  i was looking for a place to eat falafel and m...
# 121  -123.090927       4  lots of tables were available at 1130 for lunc...
# 3161  -73.713305       5  1010 ive been going to fourchette antillaise e...
# 3941  -52.710602       5  we had a great experience food was great and w...
# 2563  -63.572405       4  great bar that reminds me of a local pub back ...
# 3310  -73.654373       5  best home made jamaican pattys in westmounttea...
# 5234  -97.157773       4  fabulous hangover cure as you can see i comple...
# 3707 -104.531638       4  decent place to eat dinner food quality was go...
# 1465  -63.123657       2  the staff was kind but almost to extremes comi...
# 568  -123.100828       5  all of the dishes are delicious and i highly r...
#
#       Sentiment_score Sentiment  Positive Words Negative Words  \
# 482            0.9299      Good         [tasty]             []
# 121            0.9559      Good   [tasty, good]             []
# 3161           0.9824      Good  [great, great]             []
# 3941           0.9451      Good  [great, great]             []
# 2563           0.9806      Good   [great, good]             []
# 3310           0.7579      Good              []             []
# 5234           0.9167      Good  [great, great]             []
# 3707           0.4678       Bad          [good]             []
# 1465           0.8765      Good              []             []
# 568            0.7574      Good     [delicious]             []
#
#       Positive Count  Negative Count
# 482                1               0
# 121                2               0
# 3161               2               0
# 3941               2               0
# 2563               2               0
# 3310               0               0
# 5234               2               0
# 3707               1               0
# 1465               0               0
# 568                1               0

# %%
# Function to get the length of a review
def get_review_length(review):
    return len(review)

# Apply the function to the 'Review' column to get the review lengths
restaurants_df['Review Length'] = restaurants_df['Review'].apply(get_review_length)

# Display the DataFrame with the review lengths
print(restaurants_df[['Review', 'Review Length']])
# Out:
#                                                  Review  Review Length
# 0     busy place  strongly suggest a reservation gre...            157
# 1     i recommend squid is the best part i ordered g...            179
# 2     i really enjoyed my lunch at this cozy little ...           1025
# 3     ambiance is great with a great mixture of wood...            626
# 4     we went to the flying pig for dinner last nigh...            501
# ...                                                 ...            ...
# 5503  worst sandwich ever given a 6 veggie with fing...            441
# 5504  subway is another must stop for my family when...            247
# 5505  the service here has been on the decline for s...            414
# 5506  this place has gone downhill and staff dont ca...            506
# 5507  ive only been here twice both times ordered th...            300
#
# [5508 rows x 2 columns]

# %%
# !pip install summa

import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize
from summa.summarizer import summarize as summa_summarize

# Download the necessary resources for NLTK (run this once)
nltk.download('punkt')

# Function to extract the summary for each review
def extract_summary(review):
    # Tokenize the review into sentences
    sentences = sent_tokenize(review)
    
    # Combine sentences into a single string
    text = " ".join(sentences)
    
    # Save the original review length
    original_length = len(text)
    
    # Use summa's TextRank algorithm for extractive summarization
    summary = summa_summarize(text, ratio=0.5)
    
    # Save the summary length
    summary_length = len(summary) if summary else 0
    
    return summary, original_length, summary_length

# Apply the summarization function to the 'Review' column
restaurants_df['Review Summary'], restaurants_df['Original Review Length'], restaurants_df['Summary Length'] = zip(*restaurants_df['Review'].apply(extract_summary))

# Display the DataFrame with the summary for each review and the review lengths
print(restaurants_df)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Fabio_UofT
# [nltk_data]     SCS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#      Restaurant_name        Category  \
# 0     The Flying Pig  Canadian (New)
# 1     The Flying Pig  Canadian (New)
# 2     The Flying Pig  Canadian (New)
# 3     The Flying Pig  Canadian (New)
# 4     The Flying Pig  Canadian (New)
# ...              ...             ...
# 5503          Subway      Sandwiches
# 5504          Subway      Sandwiches
# 5505          Subway      Sandwiches
# 5506          Subway      Sandwiches
# 5507          Subway      Sandwiches
#
#                                                 Address Province   Latitude  \
# 0     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 1     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 2     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 3     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 4     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# ...                                                 ...      ...        ...
# 5503  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5504  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5505  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5506  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5507  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
#
#        Longitude  Rating                                             Review  \
# 0    -123.122038       4  busy place  strongly suggest a reservation gre...
# 1    -123.122038       4  i recommend squid is the best part i ordered g...
# 2    -123.122038       5  i really enjoyed my lunch at this cozy little ...
# 3    -123.122038       5  ambiance is great with a great mixture of wood...
# 4    -123.122038       5  we went to the flying pig for dinner last nigh...
# ...          ...     ...                                                ...
# 5503 -114.406515       1  worst sandwich ever given a 6 veggie with fing...
# 5504 -114.406515       4  subway is another must stop for my family when...
# 5505 -114.406515       1  the service here has been on the decline for s...
# 5506 -114.406515       1  this place has gone downhill and staff dont ca...
# 5507 -114.406515       4  ive only been here twice both times ordered th...
#
#       Sentiment_score Sentiment              Positive Words Negative Words  \
# 0              0.9485      Good  [busy, great, happy, good]             []
# 1              0.8979      Good                     [great]             []
# 2              0.9966      Good        [great, good, great]             []
# 3              0.9892      Good              [great, great]             []
# 4              0.9845      Good                 [excellent]             []
# ...               ...       ...                         ...            ...
# 5503           0.2960       Bad                          []             []
# 5504           0.9337      Good        [great, good, great]             []
# 5505           0.0478       Bad                          []             []
# 5506          -0.6860       Bad                          []             []
# 5507           0.4902       Bad                      [good]             []
#
#       Positive Count  Negative Count  Review Length  \
# 0                  4               0            157
# 1                  1               0            179
# 2                  3               0           1025
# 3                  2               0            626
# 4                  1               0            501
# ...              ...             ...            ...
# 5503               0               0            441
# 5504               3               0            247
# 5505               0               0            414
# 5506               0               0            506
# 5507               1               0            300
#
#                                          Review Summary  \
# 0
# 1
# 2     they have a great selection on their menu and ...
# 3     ambiance is great with a great mixture of wood...
# 4
# ...                                                 ...
# 5503
# 5504
# 5505
# 5506  continued to do a sloppy job of veggies sauce ...
# 5507
#
#       Original Review Length  Summary Length
# 0                        157               0
# 1                        179               0
# 2                       1024             800
# 3                        626             601
# 4                        501               0
# ...                      ...             ...
# 5503                     441               0
# 5504                     247               0
# 5505                     414               0
# 5506                     506             123
# 5507                     300               0
#
# [5508 rows x 18 columns]

# %%
restaurants_df.sample(10)
# Out:
#                         Restaurant_name     Category  \
# 3889                The Green Spot Cafe   Vegetarian
# 854             Sookjai Thai Restaurant         Thai
# 395                               Micha      Chinese
# 1154  Victoria Harbour House Restaurant  Steakhouses
# 2776                 Happy Veal Hot Pot      Chinese
# 1307                     Superior Pizza        Pizza
# 239             Le Crocodile Restaurant       French
# 3234                    Brazas Portugal   Portuguese
# 3774                       Mercury Cafe       Diners
# 2725                 Happy Veal Hot Pot      Chinese
#
#                                                 Address Province   Latitude  \
# 3889     1812 Hamilton Street Regina, SK S4P 2B8 Canada       SK  50.449990
# 854         893 Fort Street Victoria, BC V8W 1H7 Canada       BC  48.423961
# 395   120-4751 Garden City Road Richmond, BC V6X 3M7...       BC  49.177868
# 1154          607 Oswego St Victoria, BC V8V 4W9 Canada       BC  48.421132
# 2776      1333 S Park Street Halifax, NS B3J 2K9 Canada       NS  44.640570
# 1307      455 Simcoe Street Victoria, BC V8V 4T3 Canada       BC  48.415536
# 239     909 Burrard Street Vancouver, BC V6Z 2N2 Canada       BC  49.282539
# 3234  169A Boulevard Sainte-Rose Laval, QC H7L 1L2 C...       QC  45.615823
# 3774            2936 13th Ave Regina, SK S4T 1N7 Canada       SK  50.445688
# 2725      1333 S Park Street Halifax, NS B3J 2K9 Canada       NS  44.640570
#
#        Longitude  Rating                                             Review  \
# 3889 -104.609645       4  the coffee is good and it has a great view i w...
# 854  -123.360217       4  wow amazing quality of food and a really exoti...
# 395  -123.125541       5  if youre looking for the best sweet and sour d...
# 1154 -123.374430       5  what a fabulous meal and experience  the best ...
# 2776  -63.578214       5  great place to get hot pot in halifax although...
# 1307 -123.374854       3  some days its very good other days the amount ...
# 239  -123.125205       5  fantastic place with topnotch service since th...
# 3234  -73.784145       3  very small restaurant they give complimentary ...
# 3774 -104.623709       1  i wanted to like it so bad its an iconic locat...
# 2725  -63.578214       5  delightful experience always wanted to try hot...
#
#       Sentiment_score Sentiment          Positive Words Negative Words  \
# 3889           0.7906      Good           [good, great]             []
# 854            0.8688      Good                  [good]             []
# 395            0.9857      Good  [delicious, delicious]             []
# 1154           0.9852      Good                 [yummy]             []
# 2776           0.7974      Good                 [great]             []
# 1307           0.9381      Good                  [good]             []
# 239            0.7783      Good      [fantastic, great]             []
# 3234           0.8937      Good            [good, good]        [salty]
# 3774          -0.7980       Bad               [excited]          [bad]
# 2725           0.8642      Good       [good, delicious]             []
#
#       Positive Count  Negative Count  Review Length  \
# 3889               2               0            132
# 854                1               0            672
# 395                2               0            648
# 1154               1               0            325
# 2776               1               0            356
# 1307               1               0            188
# 239                2               0            544
# 3234               2               1            637
# 3774               1               1            346
# 2725               2               0            141
#
#                                          Review Summary  \
# 3889
# 854   nonetheless a really memorable restaurant expe...
# 395   if youre looking for the best sweet and sour d...
# 1154
# 2776
# 1307
# 239
# 3234  very small restaurant they give complimentary ...
# 3774
# 2725
#
#       Original Review Length  Summary Length
# 3889                     132               0
# 854                      672             130
# 395                      648             484
# 1154                     325               0
# 2776                     356               0
# 1307                     188               0
# 239                      544               0
# 3234                     637              77
# 3774                     346               0
# 2725                     141               0

# %%
# Save the updated DataFrame to a new CSV file
restaurants_df.to_csv("restaurants_df.csv", index=False)
