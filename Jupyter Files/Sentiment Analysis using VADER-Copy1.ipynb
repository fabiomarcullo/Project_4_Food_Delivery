# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Download VADER lexicon (only required once)
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/andreashill/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Read the dataset
restaurants_df = pd.read_csv('/Users/andreashill/Desktop/GitHub/Project_4_Food_Delivery/Resources/Restaurants_Yelp_Reviews copy.csv')

# %%
# Print DF
restaurants_df.head()
# Out:
#   Restaurant_name        Category  \
# 0  The Flying Pig  Canadian (New)
# 1  The Flying Pig  Canadian (New)
# 2  The Flying Pig  Canadian (New)
# 3  The Flying Pig  Canadian (New)
# 4  The Flying Pig  Canadian (New)
#
#                                              Address Province   Latitude  \
# 0  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 1  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 2  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 3  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 4  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
#
#     Longitude  Rating                                             Review
# 0 -123.122038       4  Busy place - strongly suggest a reservation. G...
# 1 -123.122038       4  I recommend Squid is the best part. I ordered ...
# 2 -123.122038       5  I really enjoyed my lunch at this cozy little ...
# 3 -123.122038       5  Ambiance is great with a great mixture of wood...
# 4 -123.122038       5  We went to the Flying Pig for dinner last nigh...

# %%
# Text Preprocessing
restaurants_df['Review'] = restaurants_df['Review'].astype(str)
restaurants_df['Review'] = restaurants_df['Review'].apply(lambda review: review.lower())
restaurants_df['Review'] = restaurants_df['Review'].str.replace('[^\w\s]', '')
# Out:
# /var/folders/_z/_c4_cm7j50l1wky29tsn98200000gn/T/ipykernel_32464/3173914631.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   restaurants_df['Review'] = restaurants_df['Review'].str.replace('[^\w\s]', '')

# %%
# Perform Sentiment Analysis using VADER
analyzer = SentimentIntensityAnalyzer()

def get_sentiment_polarity(review):
    return analyzer.polarity_scores(review)['compound']

restaurants_df['Sentiment_score'] = restaurants_df['Review'].apply(get_sentiment_polarity)

# %%
# Categorize reviews as positive or negative based on sentiment score
threshold = 0.5  # You can adjust this threshold based on your preference
restaurants_df['Sentiment'] = restaurants_df['Sentiment_score'].apply(lambda score: 'Good' if score >= threshold else 'Bad')

# %%
# Print DF
restaurants_df.head()
# Out:
#   Restaurant_name        Category  \
# 0  The Flying Pig  Canadian (New)
# 1  The Flying Pig  Canadian (New)
# 2  The Flying Pig  Canadian (New)
# 3  The Flying Pig  Canadian (New)
# 4  The Flying Pig  Canadian (New)
#
#                                              Address Province   Latitude  \
# 0  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 1  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 2  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 3  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 4  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
#
#     Longitude  Rating                                             Review  \
# 0 -123.122038       4  busy place  strongly suggest a reservation gre...
# 1 -123.122038       4  i recommend squid is the best part i ordered g...
# 2 -123.122038       5  i really enjoyed my lunch at this cozy little ...
# 3 -123.122038       5  ambiance is great with a great mixture of wood...
# 4 -123.122038       5  we went to the flying pig for dinner last nigh...
#
#    Sentiment_score Sentiment
# 0           0.9485      Good
# 1           0.8979      Good
# 2           0.9966      Good
# 3           0.9892      Good
# 4           0.9845      Good

# %%
# Download the necessary resources for NLTK (run this once)
nltk.download('vader_lexicon')

# Initialize the SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Custom sentiment lexicon with positive and negative words and their scores
custom_lexicon = {
    'good': 0.5, 'great': 0.6, 'excellent': 0.7, 'awesome': 0.8, 'fantastic': 0.9,
    'bad': -0.5, 'poor': -0.6, 'terrible': -0.7, 'awful': -0.8, 'horrible': -0.9,
    'busy': 0.1,  # Custom sentiment score for 'busy'
    'delicious': 0.8,
    'yummy': 0.7,
    'tasty': 0.6,
    'delectable': 0.7,
    'flavorful': 0.6,
    'mouthwatering': 0.8,
    'savory': 0.6,
    'scrumptious': 0.7,
    'heavenly': 0.8,
    'exquisite': 0.7,
    'disappointing': -0.6,
    'tasteless': -0.5,
    'bland': -0.4,
    'overcooked': -0.6,
    'undercooked': -0.6,
    'greasy': -0.5,
    'salty': -0.4,
    'soggy': -0.5,
    'stale': -0.4,
    'unappetizing': -0.6,
    'joyful': 0.7,
    'happy': 0.6,
    'delighted': 0.7,
    'pleased': 0.6,
    'content': 0.5,
    'sad': -0.6,
    'unhappy': -0.5,
    'miserable': -0.7,
    'disheartened': -0.6,
    'gloomy': -0.5,
    'angry': -0.6,
    'frustrated': -0.5,
    'irritated': -0.5,
    'enraged': -0.7,
    'excited': 0.7,
    'thrilled': 0.8,
    'ecstatic': 0.9,
    'nervous': -0.5,
    'anxious': -0.6,
    'afraid': -0.6,
    'terrified': -0.8,
    'calm': 0.5,
    'relaxed': 0.6,
    'peaceful': 0.7
}

def extract_positive_negative_words(review):
    review = str(review)  # Ensure review is in string format
    words = review.split()
    positive_words = [word for word in words if custom_lexicon.get(word.lower(), 0) > 0]
    negative_words = [word for word in words if custom_lexicon.get(word.lower(), 0) < 0]
    return positive_words, negative_words, len(positive_words), len(negative_words)

# Assuming you have your DataFrame loaded and named 'restaurants_df'
restaurants_df['Positive Words'], restaurants_df['Negative Words'], restaurants_df['Positive Count'], restaurants_df['Negative Count'] = zip(*restaurants_df['Review'].apply(extract_positive_negative_words))

# Display the new DataFrame
print(restaurants_df)
# Out:
#      Restaurant_name        Category  \
# 0     The Flying Pig  Canadian (New)
# 1     The Flying Pig  Canadian (New)
# 2     The Flying Pig  Canadian (New)
# 3     The Flying Pig  Canadian (New)
# 4     The Flying Pig  Canadian (New)
# ...              ...             ...
# 5503          Subway      Sandwiches
# 5504          Subway      Sandwiches
# 5505          Subway      Sandwiches
# 5506          Subway      Sandwiches
# 5507          Subway      Sandwiches
#
#                                                 Address Province   Latitude  \
# 0     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 1     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 2     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 3     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 4     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# ...                                                 ...      ...        ...
# 5503  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5504  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5505  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5506  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5507  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
#
#        Longitude  Rating                                             Review  \
# 0    -123.122038       4  busy place  strongly suggest a reservation gre...
# 1    -123.122038       4  i recommend squid is the best part i ordered g...
# 2    -123.122038       5  i really enjoyed my lunch at this cozy little ...
# 3    -123.122038       5  ambiance is great with a great mixture of wood...
# 4    -123.122038       5  we went to the flying pig for dinner last nigh...
# ...          ...     ...                                                ...
# 5503 -114.406515       1  worst sandwich ever given a 6 veggie with fing...
# 5504 -114.406515       4  subway is another must stop for my family when...
# 5505 -114.406515       1  the service here has been on the decline for s...
# 5506 -114.406515       1  this place has gone downhill and staff dont ca...
# 5507 -114.406515       4  ive only been here twice both times ordered th...
#
#       Sentiment_score Sentiment              Positive Words Negative Words  \
# 0              0.9485      Good  [busy, great, happy, good]             []
# 1              0.8979      Good                     [great]             []
# 2              0.9966      Good        [great, good, great]             []
# 3              0.9892      Good              [great, great]             []
# 4              0.9845      Good                 [excellent]             []
# ...               ...       ...                         ...            ...
# 5503           0.2960       Bad                          []             []
# 5504           0.9337      Good        [great, good, great]             []
# 5505           0.0478       Bad                          []             []
# 5506          -0.6860       Bad                          []             []
# 5507           0.4902       Bad                      [good]             []
#
#       Positive Count  Negative Count
# 0                  4               0
# 1                  1               0
# 2                  3               0
# 3                  2               0
# 4                  1               0
# ...              ...             ...
# 5503               0               0
# 5504               3               0
# 5505               0               0
# 5506               0               0
# 5507               1               0
#
# [5508 rows x 14 columns]
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/andreashill/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
restaurants_df.sample(10)
# Out:
#                         Restaurant_name            Category  \
# 4949                       Fusion Grill      Canadian (New)
# 794                    10 Acres Commons             Seafood
# 5384                  Feast Cafe Bistro      Canadian (New)
# 709              Il Terrazzo Ristorante             Italian
# 668                     Indian Delicacy              Indian
# 3272               Dinette Triple Crown            Southern
# 2200                         Thai Manao                Thai
# 569            Sawasdee Thai Restaurant                Thai
# 149                  Jam Cafe on Beatty  Breakfast & Brunch
# 3764  13th Avenue Food and Coffee House        Coffee & Tea
#
#                                                Address Province   Latitude  \
# 4949      550 Academy Road Winnipeg, MB R3N 0E3 Canada       MB  49.874131
# 794    620 Humboldt Street Victoria, BC V8W 1A4 Canada       BC  48.422885
# 5384     587 Ellice Avenue Winnipeg, MB R3B 1Z7 Canada       MB  49.893150
# 709     555 Johnson Street Victoria, BC V8W 1M2 Canada       BC  48.427406
# 668   1130 West pender st Vancouver, BC V6E 4A4 Canada       BC  49.287484
# 3272        6704 Rue Clark Montreal, QC H2S 3G2 Canada       QC  45.531366
# 2200   10 trinity drive Fredericton, NB E3C 0B8 Canada       NB  45.931855
# 569      4250 Main Street Vancouver, BC V5V 3P9 Canada       BC  49.247056
# 149     556 Beatty Street Vancouver, BC V6B 2L3 Canada       BC  49.280252
# 3764        3136 13th Avenue Regina, SK S4T 1P2 Canada       SK  50.445665
#
#        Longitude  Rating                                             Review  \
# 4949  -97.197411       5  our server was fantastic friendly and very kno...
# 794  -123.367803       5  great place for dinner with some of the best v...
# 5384  -97.158423       5  tried this place for the first time tonight fo...
# 709  -123.369440       4  its a great restaurant its romantic and cozy a...
# 668  -123.121601       5  it is our second day here of eating out their ...
# 3272  -73.613146       5  i usually get the fried chicken and had tried ...
# 2200  -66.663063       3  friendly staff\npepper beef was good\nserving ...
# 569  -123.100828       5  i walked into this store by accident and found...
# 149  -123.109651       5  possibly the best brunch ive had in my life th...
# 3764 -104.626641       2  stopped in for a bite on our way through sask ...
#
#       Sentiment_score Sentiment     Positive Words Negative Words  \
# 4949           0.9726      Good  [fantastic, good]             []
# 794            0.9531      Good     [great, great]             []
# 5384           0.9879      Good     [great, great]             []
# 709            0.9273      Good     [great, yummy]             []
# 668            0.8390      Good                 []             []
# 3272           0.8359      Good             [good]             []
# 2200           0.7269      Good             [good]             []
# 569            0.9657      Good       [busy, good]             []
# 149            0.9619      Good                 []             []
# 3764           0.2382       Bad             [good]             []
#
#       Positive Count  Negative Count
# 4949               2               0
# 794                2               0
# 5384               2               0
# 709                2               0
# 668                0               0
# 3272               1               0
# 2200               1               0
# 569                2               0
# 149                0               0
# 3764               1               0

# %%
# Function to get the length of a review
def get_review_length(review):
    return len(review)

# Apply the function to the 'Review' column to get the review lengths
restaurants_df['Review Length'] = restaurants_df['Review'].apply(get_review_length)

# Display the DataFrame with the review lengths
print(restaurants_df[['Review', 'Review Length']])
# Out:
#                                                  Review  Review Length
# 0     busy place  strongly suggest a reservation gre...            157
# 1     i recommend squid is the best part i ordered g...            179
# 2     i really enjoyed my lunch at this cozy little ...           1016
# 3     ambiance is great with a great mixture of wood...            624
# 4     we went to the flying pig for dinner last nigh...            501
# ...                                                 ...            ...
# 5503  worst sandwich ever given a 6 veggie with fing...            441
# 5504  subway is another must stop for my family when...            247
# 5505  the service here has been on the decline for s...            414
# 5506  this place has gone downhill and staff dont ca...            504
# 5507  ive only been here twice both times ordered th...            300
#
# [5508 rows x 2 columns]

# %%
# !pip install summa

import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize
from summa.summarizer import summarize as summa_summarize

# Download the necessary resources for NLTK (run this once)
nltk.download('punkt')

# Function to extract the summary for each review
def extract_summary(review):
    # Tokenize the review into sentences
    sentences = sent_tokenize(review)
    
    # Combine sentences into a single string
    text = " ".join(sentences)
    
    # Save the original review length
    original_length = len(text)
    
    # Use summa's TextRank algorithm for extractive summarization
    summary = summa_summarize(text, ratio=0.5)
    
    # Save the summary length
    summary_length = len(summary) if summary else 0
    
    return summary, original_length, summary_length

# Apply the summarization function to the 'Review' column
restaurants_df['Review Summary'], restaurants_df['Original Review Length'], restaurants_df['Summary Length'] = zip(*restaurants_df['Review'].apply(extract_summary))

# Display the DataFrame with the summary for each review and the review lengths
print(restaurants_df)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/andreashill/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#      Restaurant_name        Category  \
# 0     The Flying Pig  Canadian (New)
# 1     The Flying Pig  Canadian (New)
# 2     The Flying Pig  Canadian (New)
# 3     The Flying Pig  Canadian (New)
# 4     The Flying Pig  Canadian (New)
# ...              ...             ...
# 5503          Subway      Sandwiches
# 5504          Subway      Sandwiches
# 5505          Subway      Sandwiches
# 5506          Subway      Sandwiches
# 5507          Subway      Sandwiches
#
#                                                 Address Province   Latitude  \
# 0     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 1     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 2     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 3     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 4     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# ...                                                 ...      ...        ...
# 5503  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5504  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5505  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5506  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5507  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
#
#        Longitude  Rating                                             Review  \
# 0    -123.122038       4  busy place  strongly suggest a reservation gre...
# 1    -123.122038       4  i recommend squid is the best part i ordered g...
# 2    -123.122038       5  i really enjoyed my lunch at this cozy little ...
# 3    -123.122038       5  ambiance is great with a great mixture of wood...
# 4    -123.122038       5  we went to the flying pig for dinner last nigh...
# ...          ...     ...                                                ...
# 5503 -114.406515       1  worst sandwich ever given a 6 veggie with fing...
# 5504 -114.406515       4  subway is another must stop for my family when...
# 5505 -114.406515       1  the service here has been on the decline for s...
# 5506 -114.406515       1  this place has gone downhill and staff dont ca...
# 5507 -114.406515       4  ive only been here twice both times ordered th...
#
#       Sentiment_score Sentiment              Positive Words Negative Words  \
# 0              0.9485      Good  [busy, great, happy, good]             []
# 1              0.8979      Good                     [great]             []
# 2              0.9966      Good        [great, good, great]             []
# 3              0.9892      Good              [great, great]             []
# 4              0.9845      Good                 [excellent]             []
# ...               ...       ...                         ...            ...
# 5503           0.2960       Bad                          []             []
# 5504           0.9337      Good        [great, good, great]             []
# 5505           0.0478       Bad                          []             []
# 5506          -0.6860       Bad                          []             []
# 5507           0.4902       Bad                      [good]             []
#
#       Positive Count  Negative Count  \
# 0                  4               0
# 1                  1               0
# 2                  3               0
# 3                  2               0
# 4                  1               0
# ...              ...             ...
# 5503               0               0
# 5504               3               0
# 5505               0               0
# 5506               0               0
# 5507               1               0
#
#                                          Review Summary  Review Length  \
# 0                                                                  157
# 1                                                                  179
# 2     they have a great selection on their menu and ...           1016
# 3     ambiance is great with a great mixture of wood...            624
# 4                                                                  501
# ...                                                 ...            ...
# 5503                                                               441
# 5504                                                               247
# 5505                                                               414
# 5506  continued to do a sloppy job of veggies sauce ...            504
# 5507                                                               300
#
#       Original Review Length  Summary Length
# 0                        157               0
# 1                        179               0
# 2                       1015             797
# 3                        624             600
# 4                        501               0
# ...                      ...             ...
# 5503                     441               0
# 5504                     247               0
# 5505                     414               0
# 5506                     504             122
# 5507                     300               0
#
# [5508 rows x 18 columns]

# %%
restaurants_df.sample(10)
# Out:
#                Restaurant_name            Category  \
# 2724        Happy Veal Hot Pot             Chinese
# 3196            Satay Brothers         Singaporean
# 3501              Bistro Nolah            Southern
# 4835               Burnt Toast  Breakfast & Brunch
# 731                        Foo        Asian Fusion
# 2507            Gio Restaurant      Canadian (New)
# 2437         The Wooden Monkey         Gluten-Free
# 1415            The Chip Shack             Seafood
# 4679           Omai Restaurant            Japanese
# 2197  Yassou Souvlaki & Donair               Greek
#
#                                                 Address Province   Latitude  \
# 2724      1333 S Park Street Halifax, NS B3J 2K9 Canada       NS  44.640570
# 3196  3721 Rue Notre-Dame Ouest Montreal, QC H4C 1P8...       QC  45.479317
# 3501  3669 Boulevard Saint-Jean Dollard-des-Ormeaux,...       QC  45.472284
# 4835      2112 2nd Avenue Whitehorse, YT Y1A 1B9 Canada       YT  60.720224
# 731        769 Yates Street Victoria, BC V8W 1L6 Canada       BC  48.425672
# 2507          1725 Market St Halifax, NS B3J 3N9 Canada       NS  44.647330
# 2437     1707 Grafton Street Halifax, NS B3J 2C6 Canada       NS  44.647035
# 1415  2 Great George Street Charlottetown, PE C1A 4K...      PEI  46.232565
# 4679        3 Baldwin Street Toronto, ON M5T 1L1 Canada       ON  43.656080
# 2197  1111 Regent Street Fredericton, NB E3B 3Z2 Canada       NB  45.940883
#
#        Longitude  Rating                                             Review  \
# 2724  -63.578214       1  updated review\nreduced star down to 1 since t...
# 3196  -73.581874       4  a must for those who love asian food but crave...
# 3501  -73.832220       5  my favourite restaurant in montreal my boyfrie...
# 4835 -135.052950       5  i was visiting whitehorse this week for a conf...
# 731  -123.362532       5  definitely recommend  just what we needed on a...
# 2507  -63.576109       5  1010 the oysters came with their blood orange ...
# 2437  -63.575259       4  very good service with good food  the reason f...
# 1415  -63.122672       4  great little spot the vibe of this place was s...
# 4679  -79.392653       5  good food on the pricey side as portion is sma...
# 2197  -66.657264       5  food is really good with good portion they hav...
#
#       Sentiment_score Sentiment  \
# 2724           0.9141      Good
# 3196           0.8442      Good
# 3501           0.8963      Good
# 4835           0.9403      Good
# 731            0.9476      Good
# 2507           0.0000       Bad
# 2437           0.9910      Good
# 1415           0.9862      Good
# 4679           0.5719      Good
# 2197           0.9323      Good
#
#                                          Positive Words Negative Words  \
# 2724                                       [good, good]   [bad, bland]
# 3196                                                 []             []
# 3501                                                 []             []
# 4835                                                 []             []
# 731                                              [good]             []
# 2507                                                 []             []
# 2437  [good, good, good, great, good, awesome, good,...             []
# 1415                                     [great, great]             []
# 4679                                             [good]             []
# 2197                            [good, good, delicious]             []
#
#       Positive Count  Negative Count  \
# 2724               2               2
# 3196               0               0
# 3501               0               0
# 4835               0               0
# 731                1               0
# 2507               0               0
# 2437               8               0
# 1415               2               0
# 4679               1               0
# 2197               3               0
#
#                                          Review Summary  Review Length  \
# 2724  reduced star down to 1 since this restaurant h...            702
# 3196                                                               323
# 3501                                                               325
# 4835                                                               348
# 731                                                                299
# 2507                                                               117
# 2437                                                               544
# 1415  lobster roll with fries for only 22 coming fro...            545
# 4679                                                               146
# 2197                                                               177
#
#       Original Review Length  Summary Length
# 2724                     702             286
# 3196                     323               0
# 3501                     325               0
# 4835                     348               0
# 731                      299               0
# 2507                     117               0
# 2437                     544               0
# 1415                     544             363
# 4679                     146               0
# 2197                     177               0
