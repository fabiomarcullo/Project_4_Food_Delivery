# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Download VADER lexicon (only required once)
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/andreashill/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Read the dataset
restaurants_df = pd.read_csv('/Users/andreashill/Desktop/GitHub/Project_4_Food_Delivery/Resources/Restaurants_Yelp_Reviews copy.csv')

# %%
# Print DF
restaurants_df.head()
# Out:
#   Restaurant_name        Category  \
# 0  The Flying Pig  Canadian (New)
# 1  The Flying Pig  Canadian (New)
# 2  The Flying Pig  Canadian (New)
# 3  The Flying Pig  Canadian (New)
# 4  The Flying Pig  Canadian (New)
#
#                                              Address Province   Latitude  \
# 0  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 1  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 2  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 3  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 4  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
#
#     Longitude  Rating                                             Review
# 0 -123.122038       4  Busy place - strongly suggest a reservation. G...
# 1 -123.122038       4  I recommend Squid is the best part. I ordered ...
# 2 -123.122038       5  I really enjoyed my lunch at this cozy little ...
# 3 -123.122038       5  Ambiance is great with a great mixture of wood...
# 4 -123.122038       5  We went to the Flying Pig for dinner last nigh...

# %%
# Text Preprocessing
restaurants_df['Review'] = restaurants_df['Review'].astype(str)
restaurants_df['Review'] = restaurants_df['Review'].apply(lambda review: review.lower())
restaurants_df['Review'] = restaurants_df['Review'].str.replace('[^\w\s]', '')
# Out:
# /var/folders/_z/_c4_cm7j50l1wky29tsn98200000gn/T/ipykernel_32464/3173914631.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   restaurants_df['Review'] = restaurants_df['Review'].str.replace('[^\w\s]', '')

# %%
# Perform Sentiment Analysis using VADER
analyzer = SentimentIntensityAnalyzer()

def get_sentiment_polarity(review):
    return analyzer.polarity_scores(review)['compound']

restaurants_df['Sentiment_score'] = restaurants_df['Review'].apply(get_sentiment_polarity)

# %%
# Categorize reviews as positive or negative based on sentiment score
threshold = 0.5  # You can adjust this threshold based on your preference
restaurants_df['Sentiment'] = restaurants_df['Sentiment_score'].apply(lambda score: 'Good' if score >= threshold else 'Bad')

# %%
# Print DF
restaurants_df.head()
# Out:
#   Restaurant_name        Category  \
# 0  The Flying Pig  Canadian (New)
# 1  The Flying Pig  Canadian (New)
# 2  The Flying Pig  Canadian (New)
# 3  The Flying Pig  Canadian (New)
# 4  The Flying Pig  Canadian (New)
#
#                                              Address Province   Latitude  \
# 0  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 1  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 2  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 3  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 4  1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
#
#     Longitude  Rating                                             Review  \
# 0 -123.122038       4  busy place  strongly suggest a reservation gre...
# 1 -123.122038       4  i recommend squid is the best part i ordered g...
# 2 -123.122038       5  i really enjoyed my lunch at this cozy little ...
# 3 -123.122038       5  ambiance is great with a great mixture of wood...
# 4 -123.122038       5  we went to the flying pig for dinner last nigh...
#
#    Sentiment_score Sentiment
# 0           0.9485      Good
# 1           0.8979      Good
# 2           0.9966      Good
# 3           0.9892      Good
# 4           0.9845      Good

# %%
# Download the necessary resources for NLTK (run this once)
nltk.download('vader_lexicon')

# Initialize the SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Custom sentiment lexicon with positive and negative words and their scores
custom_lexicon = {
    'good': 0.5, 'great': 0.6, 'excellent': 0.7, 'awesome': 0.8, 'fantastic': 0.9,
    'bad': -0.5, 'poor': -0.6, 'terrible': -0.7, 'awful': -0.8, 'horrible': -0.9,
    'busy': 0.1,  # Custom sentiment score for 'busy'
    'delicious': 0.8,
    'yummy': 0.7,
    'tasty': 0.6,
    'delectable': 0.7,
    'flavorful': 0.6,
    'mouthwatering': 0.8,
    'savory': 0.6,
    'scrumptious': 0.7,
    'heavenly': 0.8,
    'exquisite': 0.7,
    'disappointing': -0.6,
    'tasteless': -0.5,
    'bland': -0.4,
    'overcooked': -0.6,
    'undercooked': -0.6,
    'greasy': -0.5,
    'salty': -0.4,
    'soggy': -0.5,
    'stale': -0.4,
    'unappetizing': -0.6,
    'joyful': 0.7,
    'happy': 0.6,
    'delighted': 0.7,
    'pleased': 0.6,
    'content': 0.5,
    'sad': -0.6,
    'unhappy': -0.5,
    'miserable': -0.7,
    'disheartened': -0.6,
    'gloomy': -0.5,
    'angry': -0.6,
    'frustrated': -0.5,
    'irritated': -0.5,
    'enraged': -0.7,
    'excited': 0.7,
    'thrilled': 0.8,
    'ecstatic': 0.9,
    'nervous': -0.5,
    'anxious': -0.6,
    'afraid': -0.6,
    'terrified': -0.8,
    'calm': 0.5,
    'relaxed': 0.6,
    'peaceful': 0.7
}

def extract_positive_negative_words(review):
    review = str(review)  # Ensure review is in string format
    words = review.split()
    positive_words = [word for word in words if custom_lexicon.get(word.lower(), 0) > 0]
    negative_words = [word for word in words if custom_lexicon.get(word.lower(), 0) < 0]
    return positive_words, negative_words, len(positive_words), len(negative_words)

# Assuming you have your DataFrame loaded and named 'restaurants_df'
restaurants_df['Positive Words'], restaurants_df['Negative Words'], restaurants_df['Positive Count'], restaurants_df['Negative Count'] = zip(*restaurants_df['Review'].apply(extract_positive_negative_words))

# Display the new DataFrame
print(restaurants_df)
# Out:
#      Restaurant_name        Category  \
# 0     The Flying Pig  Canadian (New)
# 1     The Flying Pig  Canadian (New)
# 2     The Flying Pig  Canadian (New)
# 3     The Flying Pig  Canadian (New)
# 4     The Flying Pig  Canadian (New)
# ...              ...             ...
# 5503          Subway      Sandwiches
# 5504          Subway      Sandwiches
# 5505          Subway      Sandwiches
# 5506          Subway      Sandwiches
# 5507          Subway      Sandwiches
#
#                                                 Address Province   Latitude  \
# 0     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 1     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 2     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 3     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# 4     1168 Hamilton Street Unit 104 Vancouver, BC V6...       BC  49.275039
# ...                                                 ...      ...        ...
# 5503  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5504  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5505  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5506  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
# 5507  100 Borden Drive Unit 21 Yellowknife, NT X1A 3...       NT  62.449950
#
#        Longitude  Rating                                             Review  \
# 0    -123.122038       4  busy place  strongly suggest a reservation gre...
# 1    -123.122038       4  i recommend squid is the best part i ordered g...
# 2    -123.122038       5  i really enjoyed my lunch at this cozy little ...
# 3    -123.122038       5  ambiance is great with a great mixture of wood...
# 4    -123.122038       5  we went to the flying pig for dinner last nigh...
# ...          ...     ...                                                ...
# 5503 -114.406515       1  worst sandwich ever given a 6 veggie with fing...
# 5504 -114.406515       4  subway is another must stop for my family when...
# 5505 -114.406515       1  the service here has been on the decline for s...
# 5506 -114.406515       1  this place has gone downhill and staff dont ca...
# 5507 -114.406515       4  ive only been here twice both times ordered th...
#
#       Sentiment_score Sentiment              Positive Words Negative Words  \
# 0              0.9485      Good  [busy, great, happy, good]             []
# 1              0.8979      Good                     [great]             []
# 2              0.9966      Good        [great, good, great]             []
# 3              0.9892      Good              [great, great]             []
# 4              0.9845      Good                 [excellent]             []
# ...               ...       ...                         ...            ...
# 5503           0.2960       Bad                          []             []
# 5504           0.9337      Good        [great, good, great]             []
# 5505           0.0478       Bad                          []             []
# 5506          -0.6860       Bad                          []             []
# 5507           0.4902       Bad                      [good]             []
#
#       Positive Count  Negative Count
# 0                  4               0
# 1                  1               0
# 2                  3               0
# 3                  2               0
# 4                  1               0
# ...              ...             ...
# 5503               0               0
# 5504               3               0
# 5505               0               0
# 5506               0               0
# 5507               1               0
#
# [5508 rows x 14 columns]
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/andreashill/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
restaurants_df.sample(10)
# Out:
#               Restaurant_name                Category  \
# 882                  The Ruby      Breakfast & Brunch
# 4119      Kenmount Restaurant                 Chinese
# 4384                Eggstatic      Breakfast & Brunch
# 2327              Tim Hortons            Coffee & Tea
# 4357       Bolan Thai Cuisine                    Thai
# 3954      Jasmines Restaurant  American (Traditional)
# 3790  Happy Garden Restaurant                 Chinese
# 2732       Happy Veal Hot Pot                 Chinese
# 1708             The Bedouins          Middle Eastern
# 5026               Cafe Dario          Latin American
#
#                                                 Address Province   Latitude  \
# 882     3110 Douglas Street Victoria, BC V8Z 3K4 Canada       BC  48.446047
# 4119     75 Kenmount Road St. John's, NL A1B 3P8 Canada       NL  47.557644
# 4384     1568 Bayview Avenue Toronto, ON M4G 3B7 Canada       ON  43.705395
# 2327    1189 Prospect St Fredericton, NB E3B 3B9 Canada       NB  45.939579
# 4357  709 Mount Pleasant Road Toronto, ON M4S 2N4 Ca...       ON  43.706634
# 3954           1 Dunns Road Mt Pearl, NL A1N 3L1 Canada       NL  47.522658
# 3790          436 Dewdney Ave Regina, SK S4N 0E9 Canada       SK  50.455399
# 2732      1333 S Park Street Halifax, NS B3J 2K9 Canada       NS  44.640570
# 1708    12832 137 Avenue NW Edmonton, AB T5L 4Y8 Canada       AB  53.600565
# 5026       1390 Erin Street Winnipeg, MB R3E 2S8 Canada       MB  49.900918
#
#        Longitude  Rating                                             Review  \
# 882  -123.371758       5  tacos chicken and waffles duck hash and the me...
# 4119  -52.755943       5  i love the old layout and the building has a c...
# 4384  -79.375294       4  great restaurant for halal brunch i absolutely...
# 2327  -66.660977       1  this tim hortons is always out of something i ...
# 4357  -79.389211       5  tasted very authentic the flavours may be too ...
# 3954  -52.778294       5  this really is a hidden gem  always friendly s...
# 3790 -104.587783       5  ask for their secret menu its absolutely delic...
# 2732  -63.578214       5  my first time having hot pot super yummy and s...
# 1708 -113.542803       5  the staff were incredibly friendly and we were...
# 5026  -97.184077       5  i got the cheapest off the lunch menu thinking...
#
#       Sentiment_score Sentiment              Positive Words Negative Words  \
# 882            0.9167      Good                [good, good]             []
# 4119           0.9753      Good  [yummy, busy, good, yummy]     [bad, bad]
# 4384           0.9689      Good               [great, busy]             []
# 2327          -0.4588       Bad                          []             []
# 4357           0.7184      Good                      [good]             []
# 3954           0.9278      Good              [great, great]             []
# 3790           0.8169      Good                 [delicious]             []
# 2732           0.9336      Good          [yummy, delicious]             []
# 1708           0.9471      Good      [delicious, delicious]             []
# 5026           0.9836      Good           [fantastic, good]             []
#
#       Positive Count  Negative Count
# 882                2               0
# 4119               4               2
# 4384               2               0
# 2327               0               0
# 4357               1               0
# 3954               2               0
# 3790               1               0
# 2732               2               0
# 1708               2               0
# 5026               2               0
